# %%
#I don't know what's going on
#I am having a really hard time understanding KMC basics
#I have read 3 papers and watched so many videos
#Having a really hard time visualizing what's going on
#Would really help if you could go over a super simple example in class

import numpy as np
from matplotlib import pyplot as plt
import random

tini = 0 
k1 = 0.015
k2 = 0.00004
k3 = 0.0004
k4 = 0.04
tfinal = 600


def eqns(rabbits, foxes)
rabbit_b = k1 * rabbits
rabbit_d = k2 * rabbits * foxes
fox_b = k3 * rabbits * foxes
fox_d = k4 * foxes
    return (rabbit_b, rabbit_d, fox_b, fox_d)

#

#Initial state
rabbit = 200
rab = np.arange(0,rabbit,1)
fox = 400
fo = np.arange(0,fox,1)



#loop
while t<tfinal 
#getting random numbers
for y in range(1):
   random.randint(0,1)
Q = sum(eqns(rab, fo))
for x in range(1):
   random.randint(0,1)
#if x*Q is more than ____
#stop
#if x*Q is less than ___
#go
if x*Q < Q:
    break
if x*Q > Q
    continue         
alleqns = (rabbit_birth, rabbit_death, fox_birth, fox_death)
dt = Q*rabbit^-1*log
t = t+dt


#References:
#KMC lecture: https://www.youtube.com/watch?v=AQJPrUxxSpk
#MC lecture: https://www.youtube.com/watch?v=OgO1gpXSUzU
#http://helper.ipam.ucla.edu/publications/matut/matut_5898_preprint.pdf
#https://www.youtube.com/watch?v=Hxobwyxiywo
